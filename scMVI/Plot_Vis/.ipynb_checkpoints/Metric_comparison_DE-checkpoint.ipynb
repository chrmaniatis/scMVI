# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Script used to aid in the DDLFC comparisons with LFC_NN and LFC_DT.

# %%
from IPython import display
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from matplotlib import cm
from matplotlib.colors import Normalize 
from tensorflow import keras
import tensorflow as tf


Root_Folder = "/content/drive/MyDrive"

code_parent_folder = "/scMVI"

scMVI_file_PBMC = '/scMVI_DDLFC_meta/PBMC/'
scMVI_file_mESC = '/scMVI_DDLFC_meta/mESC_10X/'
scMVI_file_mESC_NMT = '/scMVI_DDLFC_meta/mESC_NMT/'
MultiVI_file = '/scvi_tools_LFC_meta/MultiVI/'
scVI_file = '/scvi_tools_LFC_meta/scVI/'

#Load LFC_NN/LFC_DT and DDLFC ranges for MultiVI and scMVI respectively.

scMVI_exp1_rng_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC+ "med_1_rng_scMVI_PBMC.csv","\t",index_col=[0])
MultiVI_exp1_rng = pd.read_csv(Root_Folder + code_parent_folder + MultiVI_file + "med_1_rnd_MutliVI_rna.csv","\t",index_col=[0])
DT_exp1_rng_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "med_1_rng_Differentia_Testing.csv","\t",index_col=[0])

scMVI_exp2_rng_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC+ "med_2_rng_scMVI_PBMC.csv","\t",index_col=[0])
MultiVI_exp2_rng = pd.read_csv(Root_Folder + code_parent_folder + MultiVI_file + "med_2_rnd_MutliVI_rna.csv","\t",index_col=[0])
DT_exp2_rng_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "med_2_rng_Differentia_Testing.csv","\t",index_col=[0])

scMVI_exp3_rng_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC+ "med_3_rng_scMVI_PBMC.csv","\t",index_col=[0])
MultiVI_exp3_rng = pd.read_csv(Root_Folder + code_parent_folder + MultiVI_file + "med_3_rnd_MutliVI_rna.csv","\t",index_col=[0])
DT_exp3_rng_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "med_3_rng_Differentia_Testing.csv","\t",index_col=[0])

gn_ind = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "/gene_pbmc.tsv","\t")
ensemble_ind = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "/features.tsv","\t",index_col=[1],header=[0])
gn_ind.index = scMVI_exp1_rng_PBMC.index
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Load LFC_NN/LFC_DT and DDLFC ranges for scVI and scMVI respectively.

scMVI_exp1_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_1_rnd_scMVI_mESC_10X_rna.csv","\t",index_col=[0])
scVI_exp1_rng = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "med_1_rnd_scVI_rna.csv","\t",index_col=[0])
DT_exp1_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_1_rng_Differentia_Testing_rna.csv","\t",index_col=[0])

scMVI_exp2_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_2_rnd_scMVI_mESC_10X_rna.csv","\t",index_col=[0])
scVI_exp2_rng = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "med_2_rnd_scVI_rna.csv","\t",index_col=[0])
DT_exp2_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_2_rng_Differentia_Testing_rna.csv","\t",index_col=[0])

scMVI_exp3_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_3_rnd_scMVI_mESC_10X_rna.csv","\t",index_col=[0])
scVI_exp3_rng = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "med_3_rnd_scVI_rna.csv","\t",index_col=[0])
DT_exp3_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_3_rng_Differentia_Testing_rna.csv","\t",index_col=[0])

scMVI_exp4_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_4_rnd_scMVI_mESC_10X_rna.csv","\t",index_col=[0])
scVI_exp4_rng = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "med_4_rnd_scVI_rna.csv","\t",index_col=[0])
DT_exp4_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_4_rng_Differentia_Testing_rna.csv","\t",index_col=[0])

scMVI_exp5_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_5_rnd_scMVI_mESC_10X_rna.csv","\t",index_col=[0])
scVI_exp5_rng = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "med_5_rnd_scVI_rna.csv","\t",index_col=[0])
DT_exp5_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_5_rng_Differentia_Testing_rna.csv","\t",index_col=[0])

scMVI_exp6_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_6_rnd_scMVI_mESC_10X_rna.csv","\t",index_col=[0])
scVI_exp6_rng = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "med_6_rnd_scVI_rna.csv","\t",index_col=[0])
DT_exp6_rng_mESC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC+ "med_6_rng_Differentia_Testing_rna.csv","\t",index_col=[0])

# %%
def plot_fnc(x1,x2,ttl,x1_lab,x2_lab,sv_lnk):
        eps=0.00001
        y1 = np.log(x1.sort_index().to_numpy())
        y2 = np.log(eps+x2.sort_index().to_numpy())/np.log2(np.exp(1))
        x = np.linspace(np.minimum(np.min(y1),np.min(y2)),np.maximum(np.max(y1),np.max(y2)))
        plt.scatter(y1,y2)
        plt.plot(x,x,'r')
        plt.xlabel(x1_lab,fontsize=15) 
        plt.ylabel(x2_lab,fontsize=15) 
        plt.title(ttl,fontsize=15)
        plt.savefig(sv_lnk)
        plt.show()
        print(np.mean(y1<y2))

# %%
#Plot LFC_NN/LFC_DT vs DDLFC ranges for PBMC data.
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD14vsCD4.png"
plot_fnc(scMVI_exp1_rng_PBMC,MultiVI_exp1_rng,'CD14 Mono vs. CD4 Naive',"DDLFC Range (Log)","LFC_NN Range (Log)",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD14vsCD4_DT.png"
plot_fnc(scMVI_exp1_rng_PBMC,DT_exp1_rng_PBMC,'CD14 Mono vs. CD4 Naive',"DDLFC Range (Log)","LFC_DT Range (Log)",lnk)

lnk = Root_Folder + code_parent_folder + "/Paper_Plots/NKvsMemoryB.png"
plot_fnc(scMVI_exp3_rng_PBMC,MultiVI_exp3_rng,'NK vs. Memory B',"DDLFC Range (Log)","LFC_NN Range (Log)",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/NKvsMemoryB_DT.png"
plot_fnc(scMVI_exp3_rng_PBMC,DT_exp2_rng_PBMC,'NK vs. Memory B',"DDLFC Range (Log)","LFC_DT Range (Log)",lnk)
# Out:
# 0.9972
# 0.9496
# 0.6032
# 0.9082

# %%
#Plot LFC_NN/LFC_DT vs DDLFC ranges for mESC_Pj data.
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E80_E85.png"
plot_fnc(scMVI_exp1_rng_mESC,scVI_exp6_rng,'E8.0 to E8.5',"DDLFC Range (Log)","LFC_NN Range (Log)",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E80_E85_DT.png"
plot_fnc(scMVI_exp1_rng_mESC,DT_exp1_rng_mESC,'E8.0 to E8.5',"DDLFC Range (Log)","LFC_DT Range (Log)",lnk)

lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E70_E75.png"
plot_fnc(scMVI_exp4_rng_mESC,scVI_exp4_rng,'E7.0 to E7.5',"DDLFC Range (Log)","LFC_NN Range (Log)",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E70_E75_DT.png"
plot_fnc(scMVI_exp4_rng_mESC,DT_exp4_rng_mESC,'E7.0 to E7.5',"DDLFC Range (Log)","LFC_DT Range (Log)",lnk)


#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E775_E80.png"
#plot_fnc(scMVI_exp2_rng_mESC,scVI_exp2_rng,'E7.75 to E8.0',"DDLFC Range (Log)","LFC Range (Log)",lnk)
#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E775_E80_DT.png"
#plot_fnc(scMVI_exp2_rng_mESC,DT_exp2_rng_mESC,'E7.75 to E8.0',"DDLFC Range (Log)","DT Range (Log)",lnk)

#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E75_E775.png"
#plot_fnc(scMVI_exp3_rng_mESC,scVI_exp3_rng,'E7.5 to E7.75',"DDLFC Range (Log)","LFC Range (Log)",lnk)
#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E75_E775_DT.png"
#plot_fnc(scMVI_exp3_rng_mESC,DT_exp3_rng_mESC,'E7.5 to E7.75',"DDLFC Range (Log)","DT Range (Log)",lnk)

#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E675_E70.png"
#plot_fnc(scMVI_exp5_rng_mESC,scVI_exp5_rng,'E6.75 to E7.0',"DDLFC Range (Log)","LFC Range (Log)",lnk)
#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E675_E70_DT.png"
#plot_fnc(scMVI_exp5_rng_mESC,DT_exp5_rng_mESC,'E6.75 to E7.0',"DDLFC Range (Log)","DT Range (Log)",lnk)

#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E65_E675.png"
#plot_fnc(scMVI_exp6_rng_mESC,scVI_exp6_rng,'E6.5 to E6.75',"DDLFC Range (Log)","LFC Range (Log)",lnk)
#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E65_E675_DT.png"
#plot_fnc(scMVI_exp6_rng_mESC,DT_exp6_rng_mESC,'E6.5 to E6.75',"DDLFC Range (Log)","DT Range (Log)",lnk)
# Out:
# 0.8030926139167627
# 1.0
# 0.9914459615068267
# 1.0

# %%
#Load LFC_NN,LFC_DT and DDLFC for mESC_Pj and PBMC.

scMVI_exp1_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_1_scMVI_mESC_rna.csv","\t",index_col=[0])
scMVI_exp2_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_2_scMVI_mESC_rna.csv","\t",index_col=[0])
scMVI_exp3_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_3_scMVI_mESC_rna.csv","\t",index_col=[0])
scMVI_exp4_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_4_scMVI_mESC_rna.csv","\t",index_col=[0])
scMVI_exp5_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_5_scMVI_mESC_rna.csv","\t",index_col=[0])
scMVI_exp6_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_6_scMVI_mESC_rna.csv","\t",index_col=[0])

DT_exp1_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_1_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp2_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_2_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp3_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_3_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp4_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_4_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp5_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_5_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp6_all = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC + "Diff_Dir_6_Differentia_Testing_rna.csv","\t",index_col=[0])


scVI_exp1_all = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "Diff_Dir_1_scVI_rna.csv","\t",index_col=[0])
scVI_exp2_all = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "Diff_Dir_2_scVI_rna.csv","\t",index_col=[0])
scVI_exp3_all = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "Diff_Dir_3_scVI_rna.csv","\t",index_col=[0])
scVI_exp4_all = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "Diff_Dir_4_scVI_rna.csv","\t",index_col=[0])
scVI_exp5_all = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "Diff_Dir_5_scVI_rna.csv","\t",index_col=[0])
scVI_exp6_all = pd.read_csv(Root_Folder + code_parent_folder + scVI_file + "Diff_Dir_6_scVI_rna.csv","\t",index_col=[0])


scMVI_exp1_all_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "Diff_Dir_1_scMVI_PBMC_rna.csv","\t",index_col=[0])
scMVI_exp3_all_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "Diff_Dir_3_scMVI_PBMC_rna.csv","\t",index_col=[0])

DT_exp1_all_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "Diff_Dir_1_Differentia_Testing.csv","\t",index_col=[0])
DT_exp3_all_PBMC = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_PBMC + "Diff_Dir_3_Differentia_Testing.csv","\t",index_col=[0])

MultiVI_exp1_all = pd.read_csv(Root_Folder + code_parent_folder + MultiVI_file + "Diff_Dir_1_MutliVI_rna.csv","\t",index_col=[0])
MultiVI_exp3_all = pd.read_csv(Root_Folder + code_parent_folder + MultiVI_file + "Diff_Dir_3_MutliVI_rna.csv","\t",index_col=[0])


scMVI_exp1_mESC_NMT_rna = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_rna.csv","\t",index_col=[0])
scMVI_exp2_mESC_NMT_rna = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_rna.csv","\t",index_col=[0])
scMVI_exp3_mESC_NMT_rna = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_rna.csv","\t",index_col=[0])

scMVI_exp1_mESC_NMT_met = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_met.csv","\t",index_col=[0])
scMVI_exp2_mESC_NMT_met = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_met.csv","\t",index_col=[0])
scMVI_exp3_mESC_NMT_met = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_met.csv","\t",index_col=[0])

scMVI_exp1_mESC_NMT_acc = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_met.csv","\t",index_col=[0])
scMVI_exp2_mESC_NMT_acc = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_met.csv","\t",index_col=[0])
scMVI_exp3_mESC_NMT_acc = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_scMVI_all_met.csv","\t",index_col=[0])

DT_exp1_mESC_NMT_rna = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp2_mESC_NMT_rna = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_Differentia_Testing_rna.csv","\t",index_col=[0])
DT_exp3_mESC_NMT_rna = pd.read_csv(Root_Folder + code_parent_folder + scMVI_file_mESC_NMT+ "Diff_Dir_1_Differentia_Testing_rna.csv","\t",index_col=[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
scMVI_exp_all = pd.concat([scMVI_exp1_all,scMVI_exp2_all,scMVI_exp3_all,scMVI_exp4_all,scMVI_exp5_all,scMVI_exp6_all],axis=1)
scVI_exp_all = pd.concat([scVI_exp1_all,scVI_exp2_all,scVI_exp3_all,scVI_exp4_all,scVI_exp5_all,scVI_exp6_all],axis=1)
DT_exp_all = pd.concat([DT_exp1_all,DT_exp2_all,DT_exp3_all,DT_exp4_all,DT_exp5_all,DT_exp6_all],axis=1)

scMVI_exp_all_PBMC = pd.concat([scMVI_exp1_all_PBMC,scMVI_exp3_all_PBMC],axis=1)
MultiVI_exp_all = pd.concat([MultiVI_exp1_all,MultiVI_exp3_all],axis=1)
DT_exp_all_PBMC = pd.concat([DT_exp1_all_PBMC,DT_exp3_all_PBMC],axis=1)

scMVI_exp_all_NMT_acc = pd.concat([scMVI_exp1_mESC_NMT_acc,scMVI_exp2_mESC_NMT_acc,scMVI_exp3_mESC_NMT_acc],axis=1)
scMVI_exp_all_NMT_met = pd.concat([scMVI_exp1_mESC_NMT_met,scMVI_exp2_mESC_NMT_met,scMVI_exp3_mESC_NMT_met],axis=1)
scMVI_exp_all_NMT_rna = pd.concat([scMVI_exp1_mESC_NMT_rna,scMVI_exp2_mESC_NMT_rna,scMVI_exp3_mESC_NMT_rna],axis=1)

DT_exp_all_NMT_rna = pd.concat([DT_exp1_mESC_NMT_rna,DT_exp2_mESC_NMT_rna,DT_exp3_mESC_NMT_rna],axis=1)

# %%
DT_exp_all.columns = ["exp1","exp2","exp3","exp4","exp5","exp6"]
scMVI_exp_all.columns = ["exp1","exp2","exp3","exp4","exp5","exp6"]
scVI_exp_all.columns = ["exp1","exp2","exp3","exp4","exp5","exp6"]

scMVI_exp_all_PBMC.columns = ["exp1","exp2"]
MultiVI_exp_all.columns = ["exp1","exp2"]
DT_exp_all_PBMC.columns = ["exp1","exp2"]

scMVI_exp_all_NMT_acc.columns = ["exp1","exp2","exp3"]
scMVI_exp_all_NMT_met.columns = ["exp1","exp2","exp3"]
scMVI_exp_all_NMT_rna.columns = ["exp1","exp2","exp3"]
DT_exp_all_NMT_rna.columns = ["exp1","exp2","exp3"]

# %%
#Estimate correlation between LFC_NN/LFC_DT and DDLFC.
def plot_lfc(x1,x2,ttl,x1_lab,x2_lab,sv_link):
      xxx = np.linspace(np.min(x1),np.max(x2),100)

      plt.scatter(x1,x2)
      plt.plot(xxx,xxx,'r')
      plt.xlabel(x1_lab,fontsize=15) #"DDLFC"
      plt.ylabel(x2_lab,fontsize=15)  #"LFC"
      plt.title(ttl,fontsize=15)
      plt.savefig(sv_link)
      plt.show()
      print(np.corrcoef(x1,x2))

lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E80_E85_DDLFC_comp.png"
plot_lfc(scMVI_exp_all.loc[:,"exp1"],scVI_exp_all.loc[:,"exp6"],"E8.0 to E8.5","DDLFC","LFC_NN",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E80_E85_DDLFC_comp_DT.png"
plot_lfc(scMVI_exp_all.loc[:,"exp1"],DT_exp_all.loc[:,"exp1"],"E8.0 to E8.5","DDLFC","LFC_DT",lnk)

lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E70_E75_DDLFC_comp.png"
plot_lfc(scMVI_exp_all.loc[:,"exp4"],scVI_exp_all.loc[:,"exp3"],"E7.0 to E7.5","DDLFC","LFC_NN",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/E70_E75_DDLFC_comp_DT.png"
plot_lfc(scMVI_exp_all.loc[:,"exp4"],DT_exp_all.loc[:,"exp4"],"E7.0 to E7.5","DDLFC","LFC_DT",lnk)

lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD14vsCD4_comp.png"
plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp1"],MultiVI_exp_all.loc[:,"exp1"],"CD14 vs CD4","DDLFC","LFC_NN",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD14vsCD4_comp_DT.png"
plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp1"],DT_exp_all_PBMC.loc[:,"exp1"],"CD14 vs CD4","DDLFC","LFC_DT",lnk)

lnk = Root_Folder + code_parent_folder + "/Paper_Plots/NKvsMemoryB_comp.png"
plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp2"],MultiVI_exp_all.loc[:,"exp2"],"NK vs MemoryB","DDLFC","LFC_NN",lnk)
lnk = Root_Folder + code_parent_folder + "/Paper_Plots/NKvsMemoryB_comp_DT.png"
plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp2"],DT_exp_all_PBMC.loc[:,"exp2"],"NK vs MemoryB","DDLFC","LFC_DT",lnk)

#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD16MonovsCD14Mono_comp.png"
#plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp1"],MultiVI_exp_all.loc[:,"exp1"],"CD16 Mono vs CD14 Mono","DDLFC","LFC",lnk)
#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD16MonovsCD14Mono_comp_DT.png"
#plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp1"],DT_exp_all_PBMC.loc[:,"exp1"],"CD16 Mono vs CD14 Mono","DDLFC","DT LFC",lnk)

#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD4TEMvsCD4TCM_comp.png"
#plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp2"],MultiVI_exp_all.loc[:,"exp2"],"CD4 TEM vs CD4 TCM","DDLFC","LFC",lnk)
#lnk = Root_Folder + code_parent_folder + "/Paper_Plots/CD4TEMvsCD4TCM_comp_DT.png"
#plot_lfc(scMVI_exp_all_PBMC.loc[:,"exp2"],DT_exp_all_PBMC.loc[:,"exp2"],"CD4 TEM vs CD4 TCM","DDLFC","DT LFC",lnk)
# Out:
# [[1.         0.74778852]
#  [0.74778852 1.        ]]
# [[1.         0.76381427]
#  [0.76381427 1.        ]]
# [[1.         0.52450958]
#  [0.52450958 1.        ]]
# [[1.         0.37728699]
#  [0.37728699 1.        ]]
# [[1.         0.01686894]
#  [0.01686894 1.        ]]
# [[ 1.         -0.15013744]
#  [-0.15013744  1.        ]]
# [[ 1.         -0.01247063]
#  [-0.01247063  1.        ]]
# [[1.         0.12446111]
#  [0.12446111 1.        ]]

# %%
#Choose genomic regions with the stongest positive or negative DDLFC
def choose_lab(x,num_fts,lab):  

              ind_srt = np.argsort(x.to_numpy(),axis=0)

              for ii in range(ind_srt.shape[1]):

                    ind_lw = pd.DataFrame(x.iloc[ind_srt[:,ii][:num_fts],ii].index)
                    ind_up = pd.DataFrame(x.iloc[ind_srt[:,ii][-num_fts:],ii].index)

                    ind_lw.to_csv(Root_Folder + code_parent_folder + "/scVI_scMVI_comp/"+lab+"_lw_"+str(ii)+".csv",header=False,sep='\t',index=False)
                    ind_up.to_csv(Root_Folder + code_parent_folder + "/scVI_scMVI_comp/"+lab+"_up_"+str(ii)+".csv",header=False,sep='\t',index=False)


              ind_all = pd.DataFrame(x.index)
               
              ind_all.to_csv(Root_Folder + code_parent_folder + "/scVI_scMVI_comp/all_"+lab+".csv",header=False,sep='\t',index=False)     

choose_lab(scMVI_exp_all,500,"scMVI")
choose_lab(scVI_exp_all,500,"scVI")

choose_lab(scMVI_exp_all_NMT_acc,250,"scMVI_acc")
choose_lab(scMVI_exp_all_NMT_met,250,"scMVI_met")
choose_lab(scMVI_exp_all_NMT_rna,250,"scMVI_rna")

choose_lab(DT_exp_all_NMT_rna,250,"scMVI_rna_DT")
choose_lab(DT_exp_all,500,"scMVI_mESC_Pj_DT")
